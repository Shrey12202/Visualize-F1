# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)

df = pd.read_csv("data/final_f1_ml_laps_dataset.csv")
print("Raw shape:", df.shape)

# Clean
df = df[(df["lap_time"] > 30) & (df["lap_time"] < 200)]
df = df.dropna(subset=["sector_1_time", "sector_2_time", "sector_3_time"])

df.head()
# Out:
# Raw shape: (23983, 48)
#    season             gp_name session_name session_type driver  \
# 1    2023  Bahrain Grand Prix         Race         Race    VER
# 2    2023  Bahrain Grand Prix         Race         Race    VER
# 3    2023  Bahrain Grand Prix         Race         Race    VER
# 4    2023  Bahrain Grand Prix         Race         Race    VER
# 5    2023  Bahrain Grand Prix         Race         Race    VER
#
#               team  lap_number  lap_time  sector_1_time  sector_2_time  \
# 1  Red Bull Racing           2    97.974         31.342         42.504
# 2  Red Bull Racing           3    98.006         31.388         42.469
# 3  Red Bull Racing           4    97.976         31.271         42.642
# 4  Red Bull Racing           5    98.035         31.244         42.724
# 5  Red Bull Racing           6    97.986         31.341         42.632
#
#    sector_3_time  position  track_status  is_pit_lap compound  stint  \
# 1         24.128         1            12       False     SOFT      1
# 2         24.149         1             1       False     SOFT      1
# 3         24.063         1             1       False     SOFT      1
# 4         24.067         1             1       False     SOFT      1
# 5         24.013         1             1       False     SOFT      1
#
#    tyre_life  fresh_tyre  speed_mean  speed_max  throttle_mean  brake_mean  \
# 1          5       False  195.407713        298      60.225895    0.203857
# 2          6       False  198.095109        298      62.290761    0.184783
# 3          7       False  195.786842        299      62.092105    0.200000
# 4          8       False  197.120879        301      60.884615    0.206044
# 5          9       False  196.887363        301      60.942308    0.200549
#
#       rpm_mean  rpm_max  drs_activations  air_temp  track_temp  humidity  \
# 1  9773.179063    12063              363      27.3        31.1        22
# 2  9756.970109    11795                0      27.3        31.2        22
# 3  9723.621053    11960                0      27.2        31.1        22
# 4  9710.263736    11911                0      27.2        31.0        22
# 5  9767.299451    11852                0      27.1        31.0        22
#
#    wind_speed  wind_dir  pressure  speed_min  speed_std  speed_q1  speed_q3  \
# 1         0.0       208    1016.7       64.0  63.263189     145.5    242.50
# 2         0.6       170    1016.7       65.0  64.896809     147.0    253.00
# 3         0.8       236    1016.9       65.0  64.320556     143.5    245.75
# 4         1.0       206    1016.7       65.0  64.729756     145.0    249.25
# 5         0.6       175    1016.9       62.0  65.702778     143.0    250.75
#
#    speed_range  throttle_max  throttle_min  throttle_std  throttle_pct_full  \
# 1        234.0         100.0           0.0     43.626538           0.432507
# 2        233.0         100.0           0.0     43.299096           0.470109
# 3        234.0         100.0           0.0     43.281912           0.471053
# 4        236.0         100.0           0.0     43.751400           0.450549
# 5        239.0         100.0           0.0     43.439385           0.450549
#
#    brake_std  brake_pct_braking      rpm_std  gear_changes  gear_min  \
# 1   0.403420           0.203857  1637.445568          43.0       2.0
# 2   0.388650           0.184783  1747.054894          36.0       3.0
# 3   0.400527           0.200000  1726.074671          39.0       3.0
# 4   0.405019           0.206044  1732.516039          36.0       3.0
# 5   0.400963           0.200549  1660.594957          42.0       2.0
#
#    gear_max  drs_active_pct  drs_time_seconds
# 1       8.0             1.0         97.750285
# 2       8.0             0.0          0.000000
# 3       8.0             0.0          0.000000
# 4       8.0             0.0          0.000000
# 5       8.0             0.0          0.000000

# %%
tyre_base = df.copy()

# Remove pit laps if available
if "is_pit_lap" in tyre_base.columns:
    tyre_base = tyre_base[tyre_base["is_pit_lap"] == 0]

# Remove non-green laps if track_status exists
if "track_status" in tyre_base.columns:
    tyre_base = tyre_base[tyre_base["track_status"] == 1]

# Driver pace offset
driver_means = tyre_base.groupby("driver")["lap_time"].mean()
global_mean = tyre_base["lap_time"].mean()
driver_offset_map = (driver_means - global_mean).to_dict()

tyre_base["driver_pace_offset"] = tyre_base["driver"].map(driver_offset_map)
tyre_base["driver_pace_offset"] -= tyre_base["driver_pace_offset"].mean()

# %%
tyre_cat_features = ["gp_name", "compound"]

tyre_num_features = [
    "tyre_life", "stint", "lap_number",
    "track_temp", "air_temp", "humidity",
    "wind_speed", "wind_dir", "pressure",
    "driver_pace_offset"
]

tyre_target = "lap_time"

cols_needed = tyre_cat_features + tyre_num_features + [tyre_target]

tyre_df = tyre_base.dropna(subset=cols_needed).copy()
print("Tyre dataset:", tyre_df.shape)
# Out:
# Tyre dataset: (20541, 49)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

X_t = tyre_df[tyre_cat_features + tyre_num_features]
y_t = tyre_df[tyre_target]

X_t_train, X_t_test, y_t_train, y_t_test = train_test_split(
    X_t, y_t, test_size=0.2, random_state=42
)

num_t = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

cat_t = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

pre_tyre = ColumnTransformer([
    ("num", num_t, tyre_num_features),
    ("cat", cat_t, tyre_cat_features)
])

tyre_model = LGBMRegressor(
    n_estimators=500,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.9,
    random_state=42,
    n_jobs=-1
)

tyre_pipeline = Pipeline([
    ("pre", pre_tyre),
    ("model", tyre_model)
])

tyre_pipeline.fit(X_t_train, y_t_train)

y_t_pred = tyre_pipeline.predict(X_t_test)

print("Tyre Model Performance:")
print(" MAE :", mean_absolute_error(y_t_test, y_t_pred))
print(" RMSE:", mean_squared_error(y_t_test, y_t_pred, squared=False))
print(" R2  :", r2_score(y_t_test, y_t_pred))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000744 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1048
# [LightGBM] [Info] Number of data points in the train set: 16432, number of used features: 37
# [LightGBM] [Info] Start training from score 88.854356
# Tyre Model Performance:
#  MAE : 0.48254171841456933
#  RMSE: 1.1486896191153733
#  R2  : 0.9888824010259125
# c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
def get_driver_offset(driver_name):
    return float(driver_offset_map.get(driver_name, 0.0))

def predict_tyre_laptime(
    gp_name, compound, tyre_life, stint, lap_number,
    track_temp, air_temp, humidity,
    wind_speed, wind_dir, pressure,
    driver=None
):
    pace = get_driver_offset(driver) if driver else 0.0

    row = {
        "gp_name": gp_name,
        "compound": compound,
        "tyre_life": tyre_life,
        "stint": stint,
        "lap_number": lap_number,
        "track_temp": track_temp,
        "air_temp": air_temp,
        "humidity": humidity,
        "wind_speed": wind_speed,
        "wind_dir": wind_dir,
        "pressure": pressure,
        "driver_pace_offset": pace
    }

    return float(tyre_pipeline.predict(pd.DataFrame([row]))[0])

# %%
def estimate_pit_loss(df_full, gp_name, driver=None):
    temp = df_full[df_full["gp_name"] == gp_name]

    if driver:
        temp = temp[temp["driver"] == driver]

    if "is_pit_lap" not in temp.columns:
        return 20.0

    pit = temp[temp["is_pit_lap"] == 1]["lap_time"]
    normal = temp[temp["is_pit_lap"] == 0]["lap_time"]

    if pit.empty or normal.empty:
        return 20.0

    return float(np.clip(pit.median() - normal.median(), 10, 35))

# %%
def simulate_tyre_strategy(strategy, total_laps, pit_loss, gp_name, weather_dict, driver=None):
    laps = []
    total_time = 0
    lap_num = 1
    stint_idx = 0

    for compound, stint_len in strategy:
        stint_idx += 1
        for life in range(1, stint_len + 1):
            if lap_num > total_laps:
                break

            lt = predict_tyre_laptime(
                gp_name, compound, life, stint_idx, lap_num,
                weather_dict["track_temp"], weather_dict["air_temp"],
                weather_dict["humidity"], weather_dict["wind_speed"],
                weather_dict["wind_dir"], weather_dict["pressure"],
                driver=driver
            )

            total_time += lt
            laps.append({"lap": lap_num, "compound": compound, "lap_time_pred": lt})
            lap_num += 1

        if lap_num <= total_laps:
            total_time += pit_loss

    return total_time, pd.DataFrame(laps)

# %%
def possible_stint_lengths(total_laps):
    return list(range(10, min(30, total_laps - 10) + 1))

def generate_strategies_fast(total_laps, compounds):
    lengths = possible_stint_lengths(total_laps)
    strategies = []

    # ---------------------
    # 1-stop (2 stints)
    # ---------------------
    for c1 in compounds:
        for c2 in compounds:
            if c1 == c2:
                continue

            for s1 in lengths:
                s2 = total_laps - s1
                if s2 < 10 or s2 > 30:
                    continue
                strategies.append([(c1, s1), (c2, s2)])

    # ---------------------
    # 2-stop (3 stints)
    # ---------------------
    for c1 in compounds:
        for c2 in compounds:
            for c3 in compounds:
                if len({c1, c2, c3}) < 2:
                    continue

                for s1 in lengths:
                    for s2 in lengths:
                        s3 = total_laps - (s1 + s2)
                        if 10 <= s3 <= 30:
                            strategies.append([(c1, s1), (c2, s2), (c3, s3)])

    return strategies

# %%
def find_best_strategies(
    gp_name, total_laps, weather_dict, driver=None, top_k=5
):
    compounds = sorted(df["compound"].unique())
    pit_loss = estimate_pit_loss(df, gp_name, driver)

    strategies = generate_strategies_fast(total_laps, compounds)

    results = []
    for strat in strategies:
        tt, _ = simulate_tyre_strategy(
            strat, total_laps, pit_loss, gp_name, weather_dict, driver
        )
        results.append({"strategy": strat, "total_time": tt})

    return pd.DataFrame(results).sort_values("total_time").head(top_k)

# %%
print("=== Tyre Model: Existing Driver (VER) ===")
ver_time = predict_tyre_laptime(
    gp_name="Bahrain Grand Prix", compound="Medium",
    tyre_life=7, stint=1, lap_number=7,
    track_temp=36, air_temp=28, humidity=40,
    wind_speed=3.2, wind_dir=140, pressure=1006,
    driver="VER"
)
print("Predicted:", ver_time)
# Out:
# === Tyre Model: Existing Driver (VER) ===
# Predicted: 95.27486661838127

# %%
print("=== Tyre Model: New Driver (General Model) ===")
new_time = predict_tyre_laptime(
    gp_name="Bahrain Grand Prix", compound="Medium",
    tyre_life=7, stint=1, lap_number=7,
    track_temp=36, air_temp=28, humidity=40,
    wind_speed=3.2, wind_dir=140, pressure=1006,
    driver=None
)
print("Predicted:", new_time)
# Out:
# === Tyre Model: New Driver (General Model) ===
# Predicted: 96.25269298494379

# %%
weather = {
    "track_temp": 36,
    "air_temp": 28,
    "humidity": 40,
    "wind_speed": 3.2,
    "wind_dir": 140,
    "pressure": 1006,
}

strategy = [("Medium", 15), ("Hard", 20)]

total, df_strat = simulate_tyre_strategy(
    strategy, total_laps=35, pit_loss=22,
    gp_name="Bahrain Grand Prix",
    weather_dict=weather,
    driver=None
)
print("Total time:", total)
df_strat.head()
# Out:
# Total time: 3378.545870856079
#    lap compound  lap_time_pred
# 0    1   Medium      96.808298
# 1    2   Medium      96.808298
# 2    3   Medium      96.410751
# 3    4   Medium      96.344112
# 4    5   Medium      96.224357

# %%
weather = {
    "track_temp": 36,
    "air_temp": 28,
    "humidity": 40,
    "wind_speed": 3.2,
    "wind_dir": 140,
    "pressure": 1006,
}

# total laps for the race
race_laps = 57  # example for Bahrain

best = find_best_strategies(
    gp_name="Bahrain Grand Prix",
    total_laps=race_laps,
    weather_dict=weather,
    driver=None,   # general strategy model (new driver)
    top_k=5
)

best
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\genericpath.py:19, in exists(path)
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/sys/fs/cgroup/cpu.max'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 13
#      10 # total laps for the race
#      11 race_laps = 57  # example for Bahrain
# ---> 13 best = find_best_strategies(
#      14     gp_name="Bahrain Grand Prix",
#      15     total_laps=race_laps,
#      16     weather_dict=weather,
#      17     driver=None,   # general strategy model (new driver)
#      18     top_k=5
#      19 )
#      21 best
#
# Cell In[36], line 11, in find_best_strategies(gp_name, total_laps, weather_dict, driver, top_k)
#       9 results = []
#      10 for strat in strategies:
# ---> 11     tt, _ = simulate_tyre_strategy(
#      12         strat, total_laps, pit_loss, gp_name, weather_dict, driver
#      13     )
#      14     results.append({"strategy": strat, "total_time": tt})
#      16 return pd.DataFrame(results).sort_values("total_time").head(top_k)
#
# Cell In[34], line 13, in simulate_tyre_strategy(strategy, total_laps, pit_loss, gp_name, weather_dict, driver)
#      10 if lap_num > total_laps:
#      11     break
# ---> 13 lt = predict_tyre_laptime(
#      14     gp_name, compound, life, stint_idx, lap_num,
#      15     weather_dict["track_temp"], weather_dict["air_temp"],
#      16     weather_dict["humidity"], weather_dict["wind_speed"],
#      17     weather_dict["wind_dir"], weather_dict["pressure"],
#      18     driver=driver
#      19 )
#      21 total_time += lt
#      22 laps.append({"lap": lap_num, "compound": compound, "lap_time_pred": lt})
#
# Cell In[32], line 27, in predict_tyre_laptime(gp_name, compound, tyre_life, stint, lap_number, track_temp, air_temp, humidity, wind_speed, wind_dir, pressure, driver)
#      10 pace = get_driver_offset(driver) if driver else 0.0
#      12 row = {
#      13     "gp_name": gp_name,
#      14     "compound": compound,
#    (...)
#      24     "driver_pace_offset": pace
#      25 }
# ---> 27 return float(tyre_pipeline.predict(pd.DataFrame([row]))[0])
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\pipeline.py:603, in Pipeline.predict(self, X, **params)
#     601     for _, name, transform in self._iter(with_final=False):
#     602         Xt = transform.transform(Xt)
# --> 603     return self.steps[-1][1].predict(Xt, **params)
#     605 # metadata routing enabled
#     606 routed_params = process_routing(self, "predict", **params)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\sklearn.py:1142, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1139 # number of threads can have values with special meaning which is only applied
#    1140 # in the scikit-learn interface, these should not reach the c++ side as-is
#    1141 predict_params = _choose_param_value("num_threads", predict_params, self.n_jobs)
# -> 1142 predict_params["num_threads"] = self._process_n_jobs(predict_params["num_threads"])
#    1144 return self._Booster.predict(  # type: ignore[union-attr]
#    1145     X,
#    1146     raw_score=raw_score,
#    (...)
#    1152     **predict_params,
#    1153 )
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\sklearn.py:904, in LGBMModel._process_n_jobs(self, n_jobs)
#     902     n_jobs = _LGBMCpuCount(only_physical_cores=True)
#     903 elif n_jobs < 0:
# --> 904     n_jobs = max(_LGBMCpuCount(only_physical_cores=False) + 1 + n_jobs, 1)
#     905 return n_jobs
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\compat.py:352, in _LGBMCpuCount(only_physical_cores)
#     351 def _LGBMCpuCount(only_physical_cores: bool = True) -> int:
# --> 352     return cpu_count(only_physical_cores=only_physical_cores)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:629, in cpu_count(only_physical_cores)
#     626 if mp is None:
#     627     return 1
# --> 629 return loky.cpu_count(only_physical_cores=only_physical_cores)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\backend\context.py:119, in cpu_count(only_physical_cores)
#     111 if sys.platform == "win32":
#     112     # On Windows, attempting to use more than 61 CPUs would result in a
#     113     # OS-level error. See https://bugs.python.org/issue26903. According to
#     114     # https://learn.microsoft.com/en-us/windows/win32/procthread/processor-groups
#     115     # it might be possible to go beyond with a lot of extra work but this
#     116     # does not look easy.
#     117     os_cpu_count = min(os_cpu_count, _MAX_WINDOWS_WORKERS)
# --> 119 cpu_count_user = _cpu_count_user(os_cpu_count)
#     120 aggregate_cpu_count = max(min(os_cpu_count, cpu_count_user), 1)
#     122 if not only_physical_cores:
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\backend\context.py:224, in _cpu_count_user(os_cpu_count)
#     221 """Number of user defined available CPUs"""
#     222 cpu_count_affinity = _cpu_count_affinity(os_cpu_count)
# --> 224 cpu_count_cgroup = _cpu_count_cgroup(os_cpu_count)
#     226 # User defined soft-limit passed as a loky specific environment variable.
#     227 cpu_count_loky = int(os.environ.get("LOKY_MAX_CPU_COUNT", os_cpu_count))
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\backend\context.py:153, in _cpu_count_cgroup(os_cpu_count)
#     151 cfs_quota_fname = "/sys/fs/cgroup/cpu/cpu.cfs_quota_us"
#     152 cfs_period_fname = "/sys/fs/cgroup/cpu/cpu.cfs_period_us"
# --> 153 if os.path.exists(cpu_max_fname):
#     154     # cgroup v2
#     155     # https://www.kernel.org/doc/html/latest/admin-guide/cgroup-v2.html
#     156     with open(cpu_max_fname) as fh:
#     157         cpu_quota_us, cpu_period_us = fh.read().strip().split()
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python39\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:
